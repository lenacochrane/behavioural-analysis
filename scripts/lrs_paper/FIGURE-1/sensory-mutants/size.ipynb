# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import matplotlib.patches as mpatches
import matplotlib as mpl

# ---- Adobe-friendly fonts (must be set BEFORE plotting) ----
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42


df1 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/sensory/wiii8/size.csv')
df1['condition'] = 'wiii8'


df2 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/sensory/anosmic/size.csv')
df2['condition'] = 'anosmic'


df3 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/sensory/9047/size.csv')
df3['condition'] = '9047'

df4 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/sensory/23129/size.csv')
df4['condition'] = '23129'

df5 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/sensory/33300/size.csv')
df5['condition'] = '33300'

df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

df = df[df['distance_from_centre'] < 30]

# %%
grouped = df.groupby(['condition', 'file', 'track'])['size'].mean().reset_index()

# grouped = df.groupby(['condition', 'file'])['size'].mean().reset_index()



plt.figure(figsize=(6, 4))
sns.stripplot(data=grouped, x='condition', y='size', jitter=True, size=5, alpha=0.5, palette=['#be0f0a', '#e7533a', '#fc8c59', '#fee2bb', '#fdc38d'])
plt.show()
# Out:
# /var/folders/w9/3f6w3lj91rl9n89tt8fnjv5h0000gp/T/ipykernel_11010/1752483747.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.stripplot(data=grouped, x='condition', y='size', jitter=True, size=5, alpha=0.5, palette=['#be0f0a', '#e7533a', '#fc8c59', '#fee2bb', '#fdc38d'])
