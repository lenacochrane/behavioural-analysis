# %%
import pandas as pd 
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
df = pd.read_excel('/Volumes/lab-windingm/home/users/cochral/plug_camera/staging/kir2.1/Kir2.1.xlsx')

df
# Out:
#                       experiment Kir2.1 Collection   gal4  age day/overnight  \
# 0    2024_07_02_kir2.1_emptygal4               tue  empty    7           day
# 1    2024_07_02_kir2.1_emptygal4               tue  empty    7           day
# 2    2024_07_02_kir2.1_emptygal4               wed  empty    6           day
# 3    2024_07_02_kir2.1_emptygal4               tue  empty    7     overnight
# 4    2024_07_02_kir2.1_emptygal4               tue  empty    7     overnight
# ..                           ...               ...    ...  ...           ...
# 347            2024_08_28_kir2.1               wed  t20b1    9           day
# 348            2024_08_28_kir2.1               wed  empty    9           day
# 349            2024_08_28_kir2.1               wed  empty    9           day
# 350            2024_08_28_kir2.1               wed  empty    9           day
# 351            2024_08_28_kir2.1               wed  empty    9           day
#
#          day  hours staged  pupa number
# ...

# %%
df_emptygal4 = df[df['gal4'] == 'empty']

# %%
df_sensory = df[df['gal4'] != 'empty']

# %%
# grouped = df_emptygal4.groupby(by='day' ,dropna=True)


sns.barplot(data=df_emptygal4, x='day', y='pupa number')

plt.show()

# %%
sns.barplot(data=df_emptygal4, x='day', y='pupa number', color='blue', alpha=0.3, label='emptygal4')
sns.barplot(data=df_sensory, x='day', y='pupa number', color='green', alpha=0.3, label='sensory lines')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,6))

df['gal4 line'] = df['gal4'].apply(lambda x: 'empty' if x == 'empty' else 'line')

sns.barplot(data=df, x='day', y='pupa number', hue='gal4', palette='viridis')

plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,6))

df['gal4 line'] = df['gal4'].apply(lambda x: 'empty' if x == 'empty'  else 'line')

sns.barplot(data=df, x='day', y='pupa number', hue='gal4 line', palette='viridis')

plt.legend()

plt.title('Pupae Count per Staging Day', fontweight='bold')

plt.ylabel('Pupae Count')
plt.xlabel('Staging Day')

plt.show()
