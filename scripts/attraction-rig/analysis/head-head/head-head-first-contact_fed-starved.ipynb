# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import sys
import matplotlib.patches as mpatches
import matplotlib as mpl


# ---- Adobe-friendly fonts (must be set BEFORE plotting) ----
mpl.rcParams['pdf.fonttype'] = 42
mpl.rcParams['ps.fonttype'] = 42



df1 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/head-head/2/agarose-plates/group-housed/fed-starved/head_head_first_contact_kinematics.csv')
df1['Condition'] = 'GH'

df2 = pd.read_csv('/Volumes/lab-windingm/home/users/cochral/LRS/AttractionRig/analysis/social-isolation/head-head/2/agarose-plates/socially-isolated/fed-starved/head_head_first_contact_kinematics.csv')
df2['Condition'] = 'SI'


df = pd.concat([df1, df2], ignore_index=True)


df['role'] = df['track_id'].map({0: 'starved', 1: 'fed'})

df = df.sort_values(['Condition','file', 'track_id', 'rel_frame'])

df['heading_angle_change'] = (
    df.groupby(['Condition', 'file', 'track_id'])['heading_angle']
      .diff()
      .abs()
)


si = df[df['Condition'] == 'SI'].copy()
gh = df[df['Condition'] == 'GH'].copy()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4), sharey=True)

# SI
sns.lineplot(
    data=si,
    x='rel_frame',
    y='speed_body',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[0]
)

axes[0].axvline(0, color='black', linestyle='--', linewidth=1)
axes[0].set_title('Socially Isolated Body Speed')
axes[0].set_xlabel('Frames relative to contact')
axes[0].set_ylabel('Speed')

# GH
sns.lineplot(
    data=gh,
    x='rel_frame',
    y='speed_body',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[1]
)

axes[1].axvline(0, color='black', linestyle='--', linewidth=1)
axes[1].set_title('Group Housed Body Speed')
axes[1].set_xlabel('Frames relative to contact')
axes[1].set_ylabel('')  

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4), sharey=True)

# SI
sns.lineplot(
    data=si,
    x='rel_frame',
    y='speed_tail',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[0]
)

axes[0].axvline(0, color='black', linestyle='--', linewidth=1)
axes[0].set_title('Socially Isolated Tail Speed')
axes[0].set_xlabel('Frames relative to contact')
axes[0].set_ylabel('Speed')

# GH
sns.lineplot(
    data=gh,
    x='rel_frame',
    y='speed_tail',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[1]
)

axes[1].axvline(0, color='black', linestyle='--', linewidth=1)
axes[1].set_title('Group Housed Tail Speed')
axes[1].set_xlabel('Frames relative to contact')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4), sharey=True)

# SI
sns.lineplot(
    data=si,
    x='rel_frame',
    y='speed_head',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[0]
)

axes[0].axvline(0, color='black', linestyle='--', linewidth=1)
axes[0].set_title('Socially Isolated Head Speed')
axes[0].set_xlabel('Frames relative to contact')
axes[0].set_ylabel('Speed')

# GH
sns.lineplot(
    data=gh,
    x='rel_frame',
    y='speed_head',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[1]
)

axes[1].axvline(0, color='black', linestyle='--', linewidth=1)
axes[1].set_title('Group Housed Head Speed')
axes[1].set_xlabel('Frames relative to contact')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4), sharey=True)

# SI
sns.lineplot(
    data=si,
    x='rel_frame',
    y='heading_angle',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[0]
)

axes[0].axvline(0, color='black', linestyle='--', linewidth=1)
axes[0].set_title('Socially Isolated')
axes[0].set_xlabel('Frames relative to contact')
axes[0].set_ylabel('Heading Angle')

# GH
sns.lineplot(
    data=gh,
    x='rel_frame',
    y='heading_angle',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[1]
)

axes[1].axvline(0, color='black', linestyle='--', linewidth=1)
axes[1].set_title('Group Housed')
axes[1].set_xlabel('Frames relative to contact')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 2, figsize=(12,4), sharey=True)

# SI
sns.lineplot(
    data=si,
    x='rel_frame',
    y='heading_angle_change',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[0]
)

axes[0].axvline(0, color='black', linestyle='--', linewidth=1)
axes[0].set_title('Socially Isolated')
axes[0].set_xlabel('Frames relative to contact')
axes[0].set_ylabel('Heading Angle Change')

# GH
sns.lineplot(
    data=gh,
    x='rel_frame',
    y='heading_angle_change',
    hue='role',
    errorbar=('ci', 95),
    ax=axes[1]
)

axes[1].axvline(0, color='black', linestyle='--', linewidth=1)
axes[1].set_title('Group Housed')
axes[1].set_xlabel('Frames relative to contact')
axes[1].set_ylabel('')

plt.tight_layout()
plt.show()
